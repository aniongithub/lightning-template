# %% [markdown]
# # Training Script
#
# This notebook defines the training entrypoint. Edit this notebook to modify training behavior.
#
# The exported cells generate `src/train.py` automatically via nbdev.

# %%
#| default_exp train_classifier

# %%
#| export
from src.lightning_config import training_config

@training_config(
    model_notebook="mnist_litmodule",
    data_notebook="mnist_datamodule"
)
def main(args=None):
    """Training entrypoint supporting both CLI and notebook modes."""
    from src.train_utils import run_training
    return run_training(args)

# %% [markdown]
# ## Testing in Notebook mode
#
# Use the cells below to run training and validation in the notebook for quick iteration. Make sure to run the `Build & Hydrate` task `Shift+Ctrl+B` if you modify other notebooks before clearing Jupyter server state and re-running it, as the build step re-generates python sources.

# %% [markdown]
# ### Single step Dev run
#
# The cell below runs a single step dev run to validate the entire training cycle, including Datamodule and Model integration.

# %%
# NOT exported - for interactive dev only
from src.train_utils import run_training_notebook

run_training_notebook(
    notebook_name="train_classifier",
    args={"trainer": {"max_epochs": 1, "limit_train_batches": 10, "limit_val_batches": 10}}
)
# Out:
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# ┏━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃    ┃ Name         ┃ Type               ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0  │ net          │ SimpleDenseNet     │  336 K │ train │     0 │
# │ 1  │ net.model    │ Sequential         │  336 K │ train │     0 │
# │ 2  │ net.model.0  │ Linear             │  200 K │ train │     0 │
# │ 3  │ net.model.1  │ BatchNorm1d        │    512 │ train │     0 │
# │ 4  │ net.model.2  │ ReLU               │      0 │ train │     0 │
# │ 5  │ net.model.3  │ Linear             │ 65.8 K │ train │     0 │
# │ 6  │ net.model.4  │ BatchNorm1d        │    512 │ train │     0 │
# │ 7  │ net.model.5  │ ReLU               │      0 │ train │     0 │
# │ 8  │ net.model.6  │ Linear             │ 65.8 K │ train │     0 │
# │ 9  │ net.model.7  │ BatchNorm1d        │    512 │ train │     0 │
# │ 10 │ net.model.8  │ ReLU               │      0 │ train │     0 │
# │ 11 │ net.model.9  │ Linear             │  2.6 K │ train │     0 │
# │ 12 │ criterion    │ CrossEntropyLoss   │      0 │ train │     0 │
# │ 13 │ train_acc    │ MulticlassAccuracy │      0 │ train │     0 │
# │ 14 │ val_acc      │ MulticlassAccuracy │      0 │ train │     0 │
# │ 15 │ test_acc     │ MulticlassAccuracy │      0 │ train │     0 │
# │ 16 │ val_acc_best │ MaxMetric          │      0 │ train │     0 │
# └────┴──────────────┴────────────────────┴────────┴───────┴───────┘
# Trainable params: 336 K
# Non-trainable params: 0
# Total params: 336 K
# Total estimated model params size (MB): 1
# Modules in train mode: 17
# Modules in eval mode: 0
# Total FLOPs: 0
# /home/vscode/.local/lib/python3.11/site-packages/rich/live.py:260: UserWarning: install "ipywidgets" for Jupyter
# support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# /home/vscode/.local/lib/python3.11/site-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec,
# LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /home/vscode/.local/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The
# 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the
# `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# /home/vscode/.local/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The
# 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the
# `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# /home/vscode/.local/lib/python3.11/site-packages/pytorch_lightning/loops/fit_loop.py:317: The number of training
# batches (10) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for
# log_every_n_steps if you want to see logs for the training epoch.
# `Trainer.fit` stopped: `max_epochs=1` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ### Full Training Run
#
# Run a complete training session with all data. Adjust `max_epochs` and other trainer arguments as needed for your experiment.

# %%
# NOT exported - for interactive dev only
from src.train_utils import run_training_notebook

run_training_notebook(
    notebook_name="train_classifier",
    args={"trainer": {"max_epochs": 10}}
)
# Out:
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# /home/vscode/.local/lib/python3.11/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:881: Checkpoint directory /workspaces/lightning-template/nbs/checkpoints exists and is not empty.
# ┏━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃    ┃ Name         ┃ Type               ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0  │ net          │ SimpleDenseNet     │  336 K │ train │     0 │
# │ 1  │ net.model    │ Sequential         │  336 K │ train │     0 │
# │ 2  │ net.model.0  │ Linear             │  200 K │ train │     0 │
# │ 3  │ net.model.1  │ BatchNorm1d        │    512 │ train │     0 │
# │ 4  │ net.model.2  │ ReLU               │      0 │ train │     0 │
# │ 5  │ net.model.3  │ Linear             │ 65.8 K │ train │     0 │
# │ 6  │ net.model.4  │ BatchNorm1d        │    512 │ train │     0 │
# │ 7  │ net.model.5  │ ReLU               │      0 │ train │     0 │
# │ 8  │ net.model.6  │ Linear             │ 65.8 K │ train │     0 │
# │ 9  │ net.model.7  │ BatchNorm1d        │    512 │ train │     0 │
# │ 10 │ net.model.8  │ ReLU               │      0 │ train │     0 │
# │ 11 │ net.model.9  │ Linear             │  2.6 K │ train │     0 │
# │ 12 │ criterion    │ CrossEntropyLoss   │      0 │ train │     0 │
# │ 13 │ train_acc    │ MulticlassAccuracy │      0 │ train │     0 │
# │ 14 │ val_acc      │ MulticlassAccuracy │      0 │ train │     0 │
# │ 15 │ test_acc     │ MulticlassAccuracy │      0 │ train │     0 │
# │ 16 │ val_acc_best │ MaxMetric          │      0 │ train │     0 │
# └────┴──────────────┴────────────────────┴────────┴───────┴───────┘
# Trainable params: 336 K
# Non-trainable params: 0
# Total params: 336 K
# Total estimated model params size (MB): 1
# Modules in train mode: 17
# Modules in eval mode: 0
# Total FLOPs: 0
# `Trainer.fit` stopped: `max_epochs=10` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ### Evaluate on Test Set
#
# After training completes, run the cell below to evaluate the trained model on the test set and see final metrics.

# %%
# NOT exported - for interactive dev only
from pytorch_lightning import Trainer
from src.datamodules.mnist_datamodule import MNISTDataModule
from src.modules.mnist_litmodule import MNISTLitModule
from src.models.simpledense import SimpleDenseNet
from src.run_utils import find_best_checkpoint

# Load the best checkpoint
model, error = find_best_checkpoint(SimpleDenseNet, MNISTLitModule)

if model:
    # Run test
    datamodule = MNISTDataModule()
    trainer = Trainer(accelerator="cpu")
    results = trainer.test(model, datamodule=datamodule)
    print(f"\nTest Results: {results}")
else:
    print(f"Error: {error}")
# Out:
# Loading checkpoint: checkpoints/epoch_000.ckpt
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# /home/vscode/.local/lib/python3.11/site-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /home/vscode/.local/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# /home/vscode/.local/lib/python3.11/site-packages/rich/live.py:260: UserWarning: install "ipywidgets" for Jupyter
# support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/acc          │     0.79830002784729      │
# │         test/loss         │     1.608519196510315     │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Test Results: [{'test/loss': 1.608519196510315, 'test/acc': 0.79830002784729}]

# %% [markdown]
# ### CLI mode entry point
#
# Export __main__ so `src/train.py` can run as a script in CLI mode

# %%
#| export
if __name__ == "__main__":
    main()
