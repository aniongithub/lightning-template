# %% [markdown]
# # Training Script
#
# #| default_exp train
#
# This notebook defines the training entrypoint. Edit this notebook to modify training behavior.
#
# The exported cells generate `train.py` automatically via nbdev.

# %%
#| default_exp train

# %%
#| export
from src.lightning_config import training_config

@training_config(
    model="mnist_litmodule.yaml",
    data="mnist_datamodule.yaml"
)
def main(args=None):
    """Training entrypoint supporting both CLI and notebook modes."""
    from src.train_utils import run_training
    return run_training(args)

# %% [markdown]
# ## Dev Run
#
# Quick local test with small dataset. Run this cell interactively in the notebook.

# %%
# NOT exported - for interactive dev only
main(args={"trainer": {"init_args": {"max_epochs": 1, "limit_train_batches": 10, "limit_val_batches": 10}}})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 #| noexport
#       2
#       3 # NOT exported - for interactive dev only
# ----> 4 main(args={"trainer": {"init_args": {"max_epochs": 1, "limit_train_batches": 10, "limit_val_batches": 10}}})
#
# File /workspaces/lightning-template/src/lightning_config.py:171, in training_config.<locals>.decorator.<locals>.wrapper(args)
#     169 def wrapper(args=None):
#     170     # Call the original function with args parameter
# --> 171     return func(args=args)
#
# Cell In[2], line 11, in main(args)
#       9 """Training entrypoint supporting both CLI and notebook modes."""
#      10 from src.train_utils import run_training
# ---> 11 return run_training(args)
#
# File /workspaces/lightning-template/src/train_utils.py:123, in run_training(args)
#     120     cli = LightningCLI(MNISTLitModule, MNISTDataModule, seed_everything=42)
#     121 else:
#     122     # Notebook mode: load configs, merge overrides, instantiate and train
# --> 123     config = load_and_prepare_config(args)
#     124     model, datamodule, trainer = instantiate_components(config)
#     125     trainer.fit(model, datamodule=datamodule)
#
# File /workspaces/lightning-template/src/train_utils.py:59, in load_and_prepare_config(args)
#      56 if not config_path.exists():
#      57     config_path = Path("..") / "configs/train.yaml"
# ---> 59 config = OmegaConf.load(config_path)
#      61 # Load referenced config files
#      62 config_dir = config_path.parent
#
# File ~/.local/lib/python3.11/site-packages/omegaconf/omegaconf.py:189, in OmegaConf.load(file_)
#     186 from ._utils import get_yaml_loader
#     188 if isinstance(file_, (str, pathlib.Path)):
# --> 189     with io.open(os.path.abspath(file_), "r", encoding="utf-8") as f:
#     190         obj = yaml.load(f, Loader=get_yaml_loader())
#     191 elif getattr(file_, "read", None):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspaces/lightning-template/configs/train.yaml'
